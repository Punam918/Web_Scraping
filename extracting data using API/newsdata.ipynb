# %%
import pandas as pd
import requests

# %%
response = requests.get('https://newsapi.org/v2/everything?q=tesla&from=2024-12-17&sortBy=publishedAt&apiKey=')

# %%
pd.DataFrame(response.json()['articles'])
# Out:
#                                                source  \
# 0   {'id': None, 'name': 'Investor's Business Daily'}
# 1                    {'id': None, 'name': 'Feber.se'}
# 2                   {'id': None, 'name': '[Removed]'}
# 3                {'id': None, 'name': 'Portfolio.hu'}
# 4           {'id': 'info-money', 'name': 'InfoMoney'}
# ..                                                ...
# 95             {'id': 'le-monde', 'name': 'Le Monde'}
# 96                {'id': None, 'name': 'AutoExpress'}
# 97              {'id': None, 'name': 'Businessam.be'}
# 98            {'id': None, 'name': 'Francetvinfo.fr'}
# 99                  {'id': None, 'name': 'L'Express'}
#
#                        author  \
# 0   Investor's Business Daily
# 1           Wille Wilhelmsson
# 2                        None
# 3                Portfolio.hu
# 4                     Reuters
# ..                        ...
# 95               Piotr Smolar
# 96                 Ellis Hyde
# 97              businessam.be
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(0,100):
    response = requests.get('https://newsapi.org/v2/everything?q=tesla&from=2024-12-17&sortBy=publishedAt&apiKey=c8267475c1bd438995fc30ec0e3c9106')
    temp_df = pd.DataFrame(response.json()['articles'])
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df.shape
# Out:
# (10000, 8)

# %%
df.to_csv('tesla_news.csv')
